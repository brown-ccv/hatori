# %%
import src
# Out:
# reading
# read

# %%
data = sorted(src.g.data.sums.doc.values())

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 15))
plt.hist(data, bins=600)
plt.yscale("log")
plt.axis([1, 50000, 1, 200000])
plt.xlabel("number of words in a document")
plt.ylabel("number of documents")

plt.show()
